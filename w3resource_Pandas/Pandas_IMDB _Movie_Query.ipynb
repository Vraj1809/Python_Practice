# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Datasets/movies_metadata.csv', encoding='ISO-8859-1', on_bad_lines='skip')
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Write a Pandas program to display the movies (title, number of votes) that received specified number of votes.
result = df.loc[df.vote_count > 2000]

result[['original_title','vote_count']]
# Out:
#         original_title  vote_count
# 0            Toy Story        5415
# 1              Jumanji        2413
# 30      Twelve Monkeys        2470
# 45               Se7en        5915
# 48  The Usual Suspects        3334

# %%
# Write a Pandas program to display the movies (title, runtime) longer than 30 minutes and shorter than 360 minutes.

result = df.loc[(df.runtime > 30) & (df.runtime < 360)]

result[['original_title','runtime']]
# Out:
#                       original_title  runtime
# 0                          Toy Story     81.0
# 1                            Jumanji    104.0
# 2                   Grumpier Old Men    101.0
# 3                  Waiting to Exhale    127.0
# 4        Father of the Bride Part II    106.0
# 5                               Heat    170.0
# 6                            Sabrina    127.0
# 7                       Tom and Huck     97.0
# 8                       Sudden Death    106.0
# 9                          GoldenEye    130.0
# 10            The American President    106.0
# 11       Dracula: Dead and Loving It     88.0
# 12                             Balto     78.0
# 13                             Nixon    192.0
# 14                  Cutthroat Island    119.0
# 15                            Casino    178.0
# 16             Sense and Sensibility    136.0
# 17                        Four Rooms     98.0
# 18    Ace Ventura: When Nature Calls     90.0
# ...

# %%
# Write a Pandas program to sort movies on runtime in descending order.
new_df = df.set_index('runtime')
new_df.sort_index(ascending=False)
# Out:
#          adult                              belongs_to_collection    budget  \
# runtime
# 192.0    False                                                NaN  44000000
# 178.0    False                                                NaN  52000000
# 170.0    False                                                NaN  60000000
# 136.0    False                                                NaN  16500000
# 132.0    False                                                NaN  50000000
# 130.0    False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 129.0    False                                                NaN  29500000
# 127.0    False                                                NaN  58000000
# 127.0    False                                                NaN  16000000
# 127.0    False                                                NaN  33000000
# 124.0    False                                                NaN         0
# ...
