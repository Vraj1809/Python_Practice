# %%
# Create a dataframe of ten rows, four columns with random values. Write a Pandas program to make a gradient color mapping on a specified column

import pandas as pd
import numpy as np
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
print("Original array:")
print(df)
print("\nDataframe - Gradient color:")
df.style.background_gradient(subset=['C'])
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212 -0.770033 -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720
#
# Dataframe - Gradient color:
# <style type="text/css">
# #T_1fea2_row0_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_1fea2_row1_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1fea2_row2_col2 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_1fea2_row3_col2 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_1fea2_row4_col2 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_1fea2_row5_col2 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_1fea2_row6_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1fea2_row7_col2 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_1fea2_row8_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_1fea2_row9_col2 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1fea2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fea2_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_1fea2_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_1fea2_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_1fea2_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_1fea2_level0_col4" class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fea2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1fea2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1fea2_row0_col1" class="data row0 col1" >1.329212</td>
#       <td id="T_1fea2_row0_col2" class="data row0 col2" >-0.770033</td>
#       <td id="T_1fea2_row0_col3" class="data row0 col3" >-0.316280</td>
#       <td id="T_1fea2_row0_col4" class="data row0 col4" >-0.990810</td>
#     </tr>
#     <tr>
#       <th id="T_1fea2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1fea2_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_1fea2_row1_col1" class="data row1 col1" >-1.070816</td>
#       <td id="T_1fea2_row1_col2" class="data row1 col2" >-1.438713</td>
#       <td id="T_1fea2_row1_col3" class="data row1 col3" >0.564417</td>
#       <td id="T_1fea2_row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>
#     <tr>
#       <th id="T_1fea2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1fea2_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_1fea2_row2_col1" class="data row2 col1" >-1.626404</td>
#       <td id="T_1fea2_row2_col2" class="data row2 col2" >0.219565</td>
#       <td id="T_1fea2_row2_col3" class="data row2 col3" >0.678805</td>
#       <td id="T_1fea2_row2_col4" class="data row2 col4" >1.889273</td>
#     </tr>
#     <tr>
#       <th id="T_1fea2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1fea2_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_1fea2_row3_col1" class="data row3 col1" >0.961538</td>
#       <td id="T_1fea2_row3_col2" class="data row3 col2" >0.104011</td>
#       <td id="T_1fea2_row3_col3" class="data row3 col3" >-0.481165</td>
#       <td id="T_1fea2_row3_col4" class="data row3 col4" >0.850229</td>
#     </tr>
#     <tr>
#       <th id="T_1fea2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1fea2_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_1fea2_row4_col1" class="data row4 col1" >1.453425</td>
#       <td id="T_1fea2_row4_col2" class="data row4 col2" >1.057737</td>
#       <td id="T_1fea2_row4_col3" class="data row4 col3" >0.165562</td>
#       <td id="T_1fea2_row4_col4" class="data row4 col4" >0.515018</td>
#     </tr>
#     <tr>
#       <th id="T_1fea2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1fea2_row5_col0" class="data row5 col0" >6.000000</td>
#       <td id="T_1fea2_row5_col1" class="data row5 col1" >-1.336936</td>
#       <td id="T_1fea2_row5_col2" class="data row5 col2" >0.562861</td>
#       <td id="T_1fea2_row5_col3" class="data row5 col3" >1.392855</td>
#       <td id="T_1fea2_row5_col4" class="data row5 col4" >-0.063328</td>
#     </tr>
#     <tr>
#       <th id="T_1fea2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1fea2_row6_col0" class="data row6 col0" >7.000000</td>
#       <td id="T_1fea2_row6_col1" class="data row6 col1" >0.121668</td>
#       <td id="T_1fea2_row6_col2" class="data row6 col2" >1.207603</td>
#       <td id="T_1fea2_row6_col3" class="data row6 col3" >-0.002040</td>
#       <td id="T_1fea2_row6_col4" class="data row6 col4" >1.627796</td>
#     </tr>
#     <tr>
#       <th id="T_1fea2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1fea2_row7_col0" class="data row7 col0" >8.000000</td>
#       <td id="T_1fea2_row7_col1" class="data row7 col1" >0.354493</td>
#       <td id="T_1fea2_row7_col2" class="data row7 col2" >1.037528</td>
#       <td id="T_1fea2_row7_col3" class="data row7 col3" >-0.385684</td>
#       <td id="T_1fea2_row7_col4" class="data row7 col4" >0.519818</td>
#     </tr>
#     <tr>
#       <th id="T_1fea2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1fea2_row8_col0" class="data row8 col0" >9.000000</td>
#       <td id="T_1fea2_row8_col1" class="data row8 col1" >1.686583</td>
#       <td id="T_1fea2_row8_col2" class="data row8 col2" >-1.325963</td>
#       <td id="T_1fea2_row8_col3" class="data row8 col3" >1.428984</td>
#       <td id="T_1fea2_row8_col4" class="data row8 col4" >-2.089354</td>
#     </tr>
#     <tr>
#       <th id="T_1fea2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1fea2_row9_col0" class="data row9 col0" >10.000000</td>
#       <td id="T_1fea2_row9_col1" class="data row9 col1" >-0.129820</td>
#       <td id="T_1fea2_row9_col2" class="data row9 col2" >0.631523</td>
#       <td id="T_1fea2_row9_col3" class="data row9 col3" >-0.586538</td>
#       <td id="T_1fea2_row9_col4" class="data row9 col4" >0.290720</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create a dataframe of ten rows, four columns with random values. Write a Pandas program to make a gradient color on all the values of the said dataframe.

import pandas as pd
import numpy as np
import seaborn as sns

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
print("Original array:")
print(df)
print("\nDataframe - Gradient color:")
df.style.background_gradient()
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212 -0.770033 -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720
#
# Dataframe - Gradient color:
# <style type="text/css">
# #T_b0171_row0_col0, #T_b0171_row1_col2, #T_b0171_row2_col1, #T_b0171_row8_col4, #T_b0171_row9_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b0171_row0_col1 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_b0171_row0_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_b0171_row0_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_b0171_row0_col4 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_b0171_row1_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_b0171_row1_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_b0171_row1_col3 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_b0171_row1_col4, #T_b0171_row7_col1, #T_b0171_row9_col4 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_b0171_row2_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_b0171_row2_col2, #T_b0171_row2_col3 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_b0171_row2_col4, #T_b0171_row6_col2, #T_b0171_row8_col1, #T_b0171_row8_col3, #T_b0171_row9_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b0171_row3_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_b0171_row3_col1, #T_b0171_row7_col0 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_b0171_row3_col2 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_b0171_row3_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_b0171_row3_col4 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_b0171_row4_col0 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_b0171_row4_col1 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_b0171_row4_col2 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_b0171_row4_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_b0171_row4_col4, #T_b0171_row7_col4 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_b0171_row5_col0 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_b0171_row5_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_b0171_row5_col2 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_b0171_row5_col3 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_b0171_row5_col4 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_b0171_row6_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_b0171_row6_col1 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_b0171_row6_col3 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_b0171_row6_col4, #T_b0171_row7_col2 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_b0171_row7_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_b0171_row8_col0 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_b0171_row8_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_b0171_row9_col1 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_b0171_row9_col2 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0171">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0171_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b0171_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b0171_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b0171_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_b0171_level0_col4" class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0171_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0171_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b0171_row0_col1" class="data row0 col1" >1.329212</td>
#       <td id="T_b0171_row0_col2" class="data row0 col2" >-0.770033</td>
#       <td id="T_b0171_row0_col3" class="data row0 col3" >-0.316280</td>
#       <td id="T_b0171_row0_col4" class="data row0 col4" >-0.990810</td>
#     </tr>
#     <tr>
#       <th id="T_b0171_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b0171_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_b0171_row1_col1" class="data row1 col1" >-1.070816</td>
#       <td id="T_b0171_row1_col2" class="data row1 col2" >-1.438713</td>
#       <td id="T_b0171_row1_col3" class="data row1 col3" >0.564417</td>
#       <td id="T_b0171_row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>
#     <tr>
#       <th id="T_b0171_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b0171_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_b0171_row2_col1" class="data row2 col1" >-1.626404</td>
#       <td id="T_b0171_row2_col2" class="data row2 col2" >0.219565</td>
#       <td id="T_b0171_row2_col3" class="data row2 col3" >0.678805</td>
#       <td id="T_b0171_row2_col4" class="data row2 col4" >1.889273</td>
#     </tr>
#     <tr>
#       <th id="T_b0171_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b0171_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_b0171_row3_col1" class="data row3 col1" >0.961538</td>
#       <td id="T_b0171_row3_col2" class="data row3 col2" >0.104011</td>
#       <td id="T_b0171_row3_col3" class="data row3 col3" >-0.481165</td>
#       <td id="T_b0171_row3_col4" class="data row3 col4" >0.850229</td>
#     </tr>
#     <tr>
#       <th id="T_b0171_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b0171_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_b0171_row4_col1" class="data row4 col1" >1.453425</td>
#       <td id="T_b0171_row4_col2" class="data row4 col2" >1.057737</td>
#       <td id="T_b0171_row4_col3" class="data row4 col3" >0.165562</td>
#       <td id="T_b0171_row4_col4" class="data row4 col4" >0.515018</td>
#     </tr>
#     <tr>
#       <th id="T_b0171_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b0171_row5_col0" class="data row5 col0" >6.000000</td>
#       <td id="T_b0171_row5_col1" class="data row5 col1" >-1.336936</td>
#       <td id="T_b0171_row5_col2" class="data row5 col2" >0.562861</td>
#       <td id="T_b0171_row5_col3" class="data row5 col3" >1.392855</td>
#       <td id="T_b0171_row5_col4" class="data row5 col4" >-0.063328</td>
#     </tr>
#     <tr>
#       <th id="T_b0171_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b0171_row6_col0" class="data row6 col0" >7.000000</td>
#       <td id="T_b0171_row6_col1" class="data row6 col1" >0.121668</td>
#       <td id="T_b0171_row6_col2" class="data row6 col2" >1.207603</td>
#       <td id="T_b0171_row6_col3" class="data row6 col3" >-0.002040</td>
#       <td id="T_b0171_row6_col4" class="data row6 col4" >1.627796</td>
#     </tr>
#     <tr>
#       <th id="T_b0171_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b0171_row7_col0" class="data row7 col0" >8.000000</td>
#       <td id="T_b0171_row7_col1" class="data row7 col1" >0.354493</td>
#       <td id="T_b0171_row7_col2" class="data row7 col2" >1.037528</td>
#       <td id="T_b0171_row7_col3" class="data row7 col3" >-0.385684</td>
#       <td id="T_b0171_row7_col4" class="data row7 col4" >0.519818</td>
#     </tr>
#     <tr>
#       <th id="T_b0171_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b0171_row8_col0" class="data row8 col0" >9.000000</td>
#       <td id="T_b0171_row8_col1" class="data row8 col1" >1.686583</td>
#       <td id="T_b0171_row8_col2" class="data row8 col2" >-1.325963</td>
#       <td id="T_b0171_row8_col3" class="data row8 col3" >1.428984</td>
#       <td id="T_b0171_row8_col4" class="data row8 col4" >-2.089354</td>
#     </tr>
#     <tr>
#       <th id="T_b0171_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b0171_row9_col0" class="data row9 col0" >10.000000</td>
#       <td id="T_b0171_row9_col1" class="data row9 col1" >-0.129820</td>
#       <td id="T_b0171_row9_col2" class="data row9 col2" >0.631523</td>
#       <td id="T_b0171_row9_col3" class="data row9 col3" >-0.586538</td>
#       <td id="T_b0171_row9_col4" class="data row9 col4" >0.290720</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create a dataframe of ten rows, four columns with random values. Write a  Pandas program to display bar charts in dataframe on specified columns.

df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
print("\nBar charts in dataframe:")
df.style.bar(subset=['B', 'C'], color='#d65f5f')
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Bar charts in dataframe:
# <style type="text/css">
# #T_55020_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.1%, #d65f5f 49.1%, #d65f5f 89.2%, transparent 89.2%);
# }
# #T_55020_row0_col2, #T_55020_row4_col1 {
#   width: 10em;
# }
# #T_55020_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.8%, #d65f5f 16.8%, #d65f5f 49.1%, transparent 49.1%);
# }
# #T_55020_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.4%, transparent 54.4%);
# }
# #T_55020_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.1%, transparent 49.1%);
# }
# #T_55020_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.4%, #d65f5f 54.4%, #d65f5f 62.7%, transparent 62.7%);
# }
# #T_55020_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.1%, #d65f5f 49.1%, #d65f5f 78.1%, transparent 78.1%);
# }
# #T_55020_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.4%, #d65f5f 54.4%, #d65f5f 58.3%, transparent 58.3%);
# }
# #T_55020_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.4%, #d65f5f 54.4%, #d65f5f 94.3%, transparent 94.3%);
# }
# #T_55020_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.7%, #d65f5f 8.7%, #d65f5f 49.1%, transparent 49.1%);
# }
# #T_55020_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.4%, #d65f5f 54.4%, #d65f5f 75.6%, transparent 75.6%);
# }
# #T_55020_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.1%, #d65f5f 49.1%, #d65f5f 52.8%, transparent 52.8%);
# }
# #T_55020_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.4%, #d65f5f 54.4%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_55020_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.1%, #d65f5f 49.1%, #d65f5f 59.8%, transparent 59.8%);
# }
# #T_55020_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.4%, #d65f5f 54.4%, #d65f5f 93.6%, transparent 93.6%);
# }
# #T_55020_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.1%, #d65f5f 49.1%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_55020_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.3%, #d65f5f 4.3%, #d65f5f 54.4%, transparent 54.4%);
# }
# #T_55020_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.2%, #d65f5f 45.2%, #d65f5f 49.1%, transparent 49.1%);
# }
# #T_55020_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.4%, #d65f5f 54.4%, #d65f5f 78.2%, transparent 78.2%);
# }
# </style>
# <table id="T_55020">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55020_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_55020_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_55020_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_55020_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_55020_level0_col4" class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55020_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55020_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_55020_row0_col1" class="data row0 col1" >1.329212</td>
#       <td id="T_55020_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_55020_row0_col3" class="data row0 col3" >-0.316280</td>
#       <td id="T_55020_row0_col4" class="data row0 col4" >-0.990810</td>
#     </tr>
#     <tr>
#       <th id="T_55020_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55020_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_55020_row1_col1" class="data row1 col1" >-1.070816</td>
#       <td id="T_55020_row1_col2" class="data row1 col2" >-1.438713</td>
#       <td id="T_55020_row1_col3" class="data row1 col3" >0.564417</td>
#       <td id="T_55020_row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>
#     <tr>
#       <th id="T_55020_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55020_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_55020_row2_col1" class="data row2 col1" >-1.626404</td>
#       <td id="T_55020_row2_col2" class="data row2 col2" >0.219565</td>
#       <td id="T_55020_row2_col3" class="data row2 col3" >0.678805</td>
#       <td id="T_55020_row2_col4" class="data row2 col4" >1.889273</td>
#     </tr>
#     <tr>
#       <th id="T_55020_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55020_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_55020_row3_col1" class="data row3 col1" >0.961538</td>
#       <td id="T_55020_row3_col2" class="data row3 col2" >0.104011</td>
#       <td id="T_55020_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_55020_row3_col4" class="data row3 col4" >0.850229</td>
#     </tr>
#     <tr>
#       <th id="T_55020_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55020_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_55020_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_55020_row4_col2" class="data row4 col2" >1.057737</td>
#       <td id="T_55020_row4_col3" class="data row4 col3" >0.165562</td>
#       <td id="T_55020_row4_col4" class="data row4 col4" >0.515018</td>
#     </tr>
#     <tr>
#       <th id="T_55020_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_55020_row5_col0" class="data row5 col0" >6.000000</td>
#       <td id="T_55020_row5_col1" class="data row5 col1" >-1.336936</td>
#       <td id="T_55020_row5_col2" class="data row5 col2" >0.562861</td>
#       <td id="T_55020_row5_col3" class="data row5 col3" >1.392855</td>
#       <td id="T_55020_row5_col4" class="data row5 col4" >-0.063328</td>
#     </tr>
#     <tr>
#       <th id="T_55020_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_55020_row6_col0" class="data row6 col0" >7.000000</td>
#       <td id="T_55020_row6_col1" class="data row6 col1" >0.121668</td>
#       <td id="T_55020_row6_col2" class="data row6 col2" >1.207603</td>
#       <td id="T_55020_row6_col3" class="data row6 col3" >-0.002040</td>
#       <td id="T_55020_row6_col4" class="data row6 col4" >1.627796</td>
#     </tr>
#     <tr>
#       <th id="T_55020_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_55020_row7_col0" class="data row7 col0" >8.000000</td>
#       <td id="T_55020_row7_col1" class="data row7 col1" >0.354493</td>
#       <td id="T_55020_row7_col2" class="data row7 col2" >1.037528</td>
#       <td id="T_55020_row7_col3" class="data row7 col3" >-0.385684</td>
#       <td id="T_55020_row7_col4" class="data row7 col4" >0.519818</td>
#     </tr>
#     <tr>
#       <th id="T_55020_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_55020_row8_col0" class="data row8 col0" >9.000000</td>
#       <td id="T_55020_row8_col1" class="data row8 col1" >1.686583</td>
#       <td id="T_55020_row8_col2" class="data row8 col2" >-1.325963</td>
#       <td id="T_55020_row8_col3" class="data row8 col3" >1.428984</td>
#       <td id="T_55020_row8_col4" class="data row8 col4" >-2.089354</td>
#     </tr>
#     <tr>
#       <th id="T_55020_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_55020_row9_col0" class="data row9 col0" >10.000000</td>
#       <td id="T_55020_row9_col1" class="data row9 col1" >-0.129820</td>
#       <td id="T_55020_row9_col2" class="data row9 col2" >0.631523</td>
#       <td id="T_55020_row9_col3" class="data row9 col3" >-0.586538</td>
#       <td id="T_55020_row9_col4" class="data row9 col4" >nan</td>
#     </tr>
#   </tbody>
# </table>
